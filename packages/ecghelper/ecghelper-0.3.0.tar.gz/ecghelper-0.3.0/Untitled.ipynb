# %%
import os
import numpy as np
from pathlib import Path

from ecghelper.waveform import WaveformRecord

# inputs
data_path = Path('tests/data').resolve()

# %%
import matplotlib.pyplot as plt

record = WaveformRecord.from_xml(data_path / '82000.xml')
plt.plot(record.data[:, 0])
plt.show()

# %%
record = WaveformRecord.from_xml(data_path / '82000_rhythm.xml')
plt.plot(record.data[:, 0])
plt.show()
