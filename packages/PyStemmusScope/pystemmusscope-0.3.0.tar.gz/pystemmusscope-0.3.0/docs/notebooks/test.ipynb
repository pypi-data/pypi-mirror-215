# %%
import pandas as pd

# %%
file = "fluxes"
df_pre = pd.read_csv(
    f"/home/bart/git/STEMMUS_SCOPE/.data/workdir/output/pre_global_N61-847_E24-295_2023-02-16-1539/{file}.csv",
    skiprows=[1],
)
df_post = pd.read_csv(
    f"/home/bart/git/STEMMUS_SCOPE/.data/workdir/output/post_global_N61-847_E24-295_2023-02-16-1539/{file}.csv",
    skiprows=[1],
)

# %%
df_pre.keys()
# Out:
# Index(['simulation_number', 'nu_iterations', 'year', 'DoY', 'Rntot', 'lEtot',
#        'Htot', 'Rnctot', 'lEctot', 'Hctot', 'Actot', 'Rnstot', 'lEstot',
#        'Hstot', 'Gtot', 'Resp', 'aPAR', 'aPAR_Cab', 'aPAR/rad.PAR', 'aPAR_Wm2',
#        'PAR', 'rad.Eoutf', 'rad.Eoutf./fluxes.aPAR_Wm2', 'Trap', 'Evap', 'ET',
#        'GPP', 'NEE'],
#       dtype='object')

# %%
var = "aPAR"
df_pre[var].plot()
df_post[var].plot()
# Out:
# <Axes: >
